# %%
# !nvidia-smi
# Out:
# Sat Sep 17 17:52:35 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Load necessary packages

# %%
# !pip install keybert
# !pip install keyphrase-vectorizers
# !pip install -U sentence-transformers
# !pip install hnswlib
# !pip install spacy[transformers]
# !pip install pytextrank

# !python -m spacy download en_core_web_trf
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      |████████████████████████████████| 85 kB 4.2 MB/s
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.22.1-py3-none-any.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 63.4 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.64.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.12.1+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.13.1+cu113)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.7.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (3.7)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 62.1 MB/s
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.9.1-py3-none-any.whl (120 kB)
#      |████████████████████████████████| 120 kB 74.5 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.1.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.8.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers) (3.0.9)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 63.8 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.6.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->huggingface-hub>=0.4.0->sentence-transformers) (3.8.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (7.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers) (7.1.2)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=389c44ee3384d6921b5154aa76d8edcc7fedd9ea68a1c219fced1c42d1518331
#   Stored in directory: /root/.cache/pip/wheels/bf/06/fb/d59c1e5bd1dac7f6cf61ec0036cc3a10ab8fecaa6b2c3d3ee9
# Successfully built sentence-transformers
# Installing collected packages: tokenizers, huggingface-hub, transformers, sentencepiece, sentence-transformers
# Successfully installed huggingface-hub-0.9.1 sentence-transformers-2.2.2 sentencepiece-0.1.97 tokenizers-0.12.1 transformers-4.22.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting hnswlib
#   Downloading hnswlib-0.6.2.tar.gz (31 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from hnswlib) (1.21.6)
# Building wheels for collected packages: hnswlib
#   Building wheel for hnswlib (PEP 517) ... done
#   Created wheel for hnswlib: filename=hnswlib-0.6.2-cp37-cp37m-linux_x86_64.whl size=1465092 sha256=d8e6cb0c5a5040e2c7d56d1040bd0d90922424563ada20ade9a4fd3eacbaec8f
#   Stored in directory: /root/.cache/pip/wheels/67/01/80/9805daef8cd398ceb20003af220f77c4689cab8e43d466481b
# Successfully built hnswlib
# Installing collected packages: hnswlib
# Successfully installed hnswlib-0.6.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy[transformers] in /usr/local/lib/python3.7/dist-packages (3.4.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy[transformers]) (1.0.8)
# Requirement already satisfied: typing-extensions<4.2.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy[transformers]) (4.1.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy[transformers]) (3.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy[transformers]) (3.0.7)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy[transformers]) (0.10.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy[transformers]) (57.4.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy[transformers]) (0.6.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy[transformers]) (2.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy[transformers]) (3.3.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy[transformers]) (1.21.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy[transformers]) (4.64.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy[transformers]) (8.1.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy[transformers]) (1.9.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy[transformers]) (1.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy[transformers]) (2.23.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy[transformers]) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy[transformers]) (21.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy[transformers]) (0.4.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy[transformers]) (2.0.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy[transformers]) (2.11.3)
# Collecting spacy-transformers<1.2.0,>=1.1.2
#   Downloading spacy_transformers-1.1.8-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 2.4 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy[transformers]) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy[transformers]) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy[transformers]) (5.2.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy[transformers]) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy[transformers]) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy[transformers]) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy[transformers]) (2022.6.15)
# Collecting spacy-alignments<1.0.0,>=0.7.2
#   Downloading spacy_alignments-0.8.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 65.2 MB/s
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from spacy-transformers<1.2.0,>=1.1.2->spacy[transformers]) (1.12.1+cu113)
# Collecting transformers<4.22.0,>=3.4.0
#   Downloading transformers-4.21.3-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 44.2 MB/s
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.7/dist-packages (from thinc<8.2.0,>=8.1.0->spacy[transformers]) (0.7.8)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->spacy[transformers]) (2022.6.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->spacy[transformers]) (4.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->spacy[transformers]) (0.9.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->spacy[transformers]) (3.8.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->spacy[transformers]) (0.12.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->spacy[transformers]) (6.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy[transformers]) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy[transformers]) (2.0.1)
# Installing collected packages: transformers, spacy-alignments, spacy-transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.22.1
#     Uninstalling transformers-4.22.1:
#       Successfully uninstalled transformers-4.22.1
# Successfully installed spacy-alignments-0.8.5 spacy-transformers-1.1.8 transformers-4.21.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytextrank
#   Downloading pytextrank-3.2.4-py3-none-any.whl (30 kB)
# Collecting graphviz>=0.13
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 4.3 MB/s
# Requirement already satisfied: spacy>=3.0 in /usr/local/lib/python3.7/dist-packages (from pytextrank) (3.4.1)
# Collecting pygments>=2.7.4
#   Downloading Pygments-2.13.0-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 61.3 MB/s
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.7/dist-packages (from pytextrank) (1.7.3)
# Requirement already satisfied: networkx[default]>=2.6 in /usr/local/lib/python3.7/dist-packages (from pytextrank) (2.6.3)
# Collecting icecream>=2.1
#   Downloading icecream-2.1.3-py2.py3-none-any.whl (8.4 kB)
# Collecting colorama>=0.3.9
#   Downloading colorama-0.4.5-py2.py3-none-any.whl (16 kB)
# Collecting asttokens>=2.0.1
#   Downloading asttokens-2.0.8-py2.py3-none-any.whl (23 kB)
# Collecting executing>=0.3.1
#   Downloading executing-1.0.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from asttokens>=2.0.1->icecream>=2.1->pytextrank) (1.15.0)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.7/dist-packages (from networkx[default]>=2.6->pytextrank) (1.21.6)
# Collecting matplotlib>=3.3
#   Downloading matplotlib-3.5.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 64.9 MB/s
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.7/dist-packages (from networkx[default]>=2.6->pytextrank) (1.3.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->networkx[default]>=2.6->pytextrank) (21.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->networkx[default]>=2.6->pytextrank) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->networkx[default]>=2.6->pytextrank) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->networkx[default]>=2.6->pytextrank) (7.1.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.37.2-py3-none-any.whl (959 kB)
#      |████████████████████████████████| 959 kB 65.3 MB/s
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->networkx[default]>=2.6->pytextrank) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->networkx[default]>=2.6->pytextrank) (2.8.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib>=3.3->networkx[default]>=2.6->pytextrank) (4.1.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1->networkx[default]>=2.6->pytextrank) (2022.2.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (0.4.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (57.4.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (3.0.10)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (1.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (1.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (2.11.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (0.10.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (2.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (2.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (2.23.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (2.4.4)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (1.0.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (3.3.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (8.1.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (0.6.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (4.64.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0->pytextrank) (3.0.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy>=3.0->pytextrank) (3.8.1)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy>=3.0->pytextrank) (5.2.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (3.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.7/dist-packages (from thinc<8.2.0,>=8.1.0->spacy>=3.0->pytextrank) (0.7.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy>=3.0->pytextrank) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy>=3.0->pytextrank) (2.0.1)
# Installing collected packages: fonttools, pygments, matplotlib, executing, colorama, asttokens, icecream, graphviz, pytextrank
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.6.1
#     Uninstalling Pygments-2.6.1:
#       Successfully uninstalled Pygments-2.6.1
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.10.1
#     Uninstalling graphviz-0.10.1:
#       Successfully uninstalled graphviz-0.10.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# Successfully installed asttokens-2.0.8 colorama-0.4.5 executing-1.0.0 fonttools-4.37.2 graphviz-0.20.1 icecream-2.1.3 matplotlib-3.5.3 pygments-2.13.0 pytextrank-3.2.4
# 2022-09-17 21:03:31.608497: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-trf==3.4.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.4.0/en_core_web_trf-3.4.0-py3-none-any.whl (460.3 MB)
#      |████████████████████████████████| 460.3 MB 39 kB/s
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from en-core-web-trf==3.4.0) (3.4.1)
# Requirement already satisfied: spacy-transformers<1.2.0,>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from en-core-web-trf==3.4.0) (1.1.8)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (1.21.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (1.9.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (3.0.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (2.0.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (2.11.3)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (0.6.2)
# Requirement already satisfied: typing-extensions<4.2.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (4.1.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (8.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (21.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (2.4.4)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (1.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (2.23.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (3.0.10)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (0.4.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (57.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (0.10.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (4.64.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (1.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (5.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (2.10)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from spacy-transformers<1.2.0,>=1.1.2->en-core-web-trf==3.4.0) (1.12.1+cu113)
# Requirement already satisfied: transformers<4.22.0,>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy-transformers<1.2.0,>=1.1.2->en-core-web-trf==3.4.0) (4.21.3)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from spacy-transformers<1.2.0,>=1.1.2->en-core-web-trf==3.4.0) (0.8.5)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.7/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (0.7.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->en-core-web-trf==3.4.0) (3.8.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->en-core-web-trf==3.4.0) (4.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->en-core-web-trf==3.4.0) (0.9.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->en-core-web-trf==3.4.0) (0.12.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->en-core-web-trf==3.4.0) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->en-core-web-trf==3.4.0) (2022.6.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-trf==3.4.0) (2.0.1)
# Installing collected packages: en-core-web-trf
# Successfully installed en-core-web-trf-3.4.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')

# %% [markdown]
# # Import Packages:

# %%
import os
import re
import ast
import pickle
import time
import spacy
import hnswlib
import pytextrank
import numpy as np
import pandas as pd
from spacy.lang.en import English
from spacy.lang.en.stop_words import STOP_WORDS
from sentence_transformers import SentenceTransformer, util
from keybert import KeyBERT
from keyphrase_vectorizers import KeyphraseTfidfVectorizer


pd.set_option("display.max_columns", None)

# %% [markdown]
# # Load Dataset

# %%
# !unzip /content/superhero_nlp.zip -d '/content/'
# Out:
# Archive:  /content/superhero_nlp.zip
#   inflating: /content/superheroes_nlp_dataset.csv

# %%
df = pd.read_csv('/content/superheroes_nlp_dataset.csv')

# %%
print(f'Number of rows: {len(df)}')
print(f'Number of columns: {len(df.columns)}')
df.info()
# Out:
# Number of rows: 1450
# Number of columns: 81
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 81 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   name                              1448 non-null   object
#  1   real_name                         1301 non-null   object
#  2   full_name                         956 non-null    object
#  3   overall_score                     1450 non-null   object
#  4   history_text                      1360 non-null   object
#  5   powers_text                       1086 non-null   object
#  6   intelligence_score                1450 non-null   int64
#  7   strength_score                    1450 non-null   int64
#  8   speed_score                       1450 non-null   int64
#  9   durability_score                  1450 non-null   int64
#  10  power_score                       1450 non-null   int64
#  11  combat_score                      1450 non-null   int64
#  12  superpowers                       1450 non-null   object
#  13  alter_egos                        1450 non-null   object
#  14  aliases                           1450 non-null   object
#  15  place_of_birth                    788 non-null    object
#  16  first_appearance                  1247 non-null   object
#  17  creator                           1311 non-null   object
#  18  alignment                         1368 non-null   object
#  19  occupation                        1014 non-null   object
#  20  base                              878 non-null    object
#  21  teams                             1450 non-null   object
#  22  relatives                         901 non-null    object
#  23  gender                            1305 non-null   object
#  24  type_race                         1043 non-null   object
#  25  height                            1448 non-null   object
#  26  weight                            1448 non-null   object
#  27  eye_color                         1186 non-null   object
#  28  hair_color                        1202 non-null   object
#  29  skin_color                        173 non-null    object
#  30  img                               1363 non-null   object
#  31  has_electrokinesis                1383 non-null   float64
#  32  has_energy_constructs             1383 non-null   float64
#  33  has_mind_control_resistance       1383 non-null   float64
#  34  has_matter_manipulation           1383 non-null   float64
#  35  has_telepathy_resistance          1383 non-null   float64
#  36  has_mind_control                  1383 non-null   float64
#  37  has_enhanced_hearing              1383 non-null   float64
#  38  has_dimensional_travel            1383 non-null   float64
#  39  has_element_control               1383 non-null   float64
#  40  has_size_changing                 1383 non-null   float64
#  41  has_fire_resistance               1383 non-null   float64
#  42  has_fire_control                  1383 non-null   float64
#  43  has_dexterity                     1383 non-null   float64
#  44  has_reality_warping               1383 non-null   float64
#  45  has_illusions                     1383 non-null   float64
#  46  has_energy_beams                  1383 non-null   float64
#  47  has_peak_human_condition          1383 non-null   float64
#  48  has_shapeshifting                 1383 non-null   float64
#  49  has_heat_resistance               1383 non-null   float64
#  50  has_jump                          1383 non-null   float64
#  51  has_self-sustenance               1383 non-null   float64
#  52  has_energy_absorption             1383 non-null   float64
#  53  has_cold_resistance               1383 non-null   float64
#  54  has_magic                         1383 non-null   float64
#  55  has_telekinesis                   1383 non-null   float64
#  56  has_toxin_and_disease_resistance  1383 non-null   float64
#  57  has_telepathy                     1383 non-null   float64
#  58  has_regeneration                  1383 non-null   float64
#  59  has_immortality                   1383 non-null   float64
#  60  has_teleportation                 1383 non-null   float64
#  61  has_force_fields                  1383 non-null   float64
#  62  has_energy_manipulation           1383 non-null   float64
#  63  has_endurance                     1383 non-null   float64
#  64  has_longevity                     1383 non-null   float64
#  65  has_weapon-based_powers           1383 non-null   float64
#  66  has_energy_blasts                 1383 non-null   float64
#  67  has_enhanced_senses               1383 non-null   float64
#  68  has_invulnerability               1383 non-null   float64
#  69  has_stealth                       1383 non-null   float64
#  70  has_marksmanship                  1383 non-null   float64
#  71  has_flight                        1383 non-null   float64
#  72  has_accelerated_healing           1383 non-null   float64
#  73  has_weapons_master                1383 non-null   float64
#  74  has_intelligence                  1383 non-null   float64
#  75  has_reflexes                      1383 non-null   float64
#  76  has_super_speed                   1383 non-null   float64
#  77  has_durability                    1383 non-null   float64
#  78  has_stamina                       1383 non-null   float64
#  79  has_agility                       1383 non-null   float64
#  80  has_super_strength                1383 non-null   float64
# dtypes: float64(50), int64(6), object(25)
# memory usage: 917.7+ KB

# %%
def get_record(index:int, data:pd.DataFrame=df) -> dict:
  record = data.iloc[index]
  return dict(record)

# %%
get_record(96)
# Out:
# {'name': 'Aspheera',
#  'real_name': 'Aspheera',
#  'full_name': 'Aspheera',
#  'overall_score': '67',
#  'history_text': "Aspheera is the leader of the Pyro Vipers and a Serpentine sorceress. In her youth, she forged a friendship with a young Wu in a bid to learn Spinjitzu and secretly overthrow Mambo the Fifth. After Wu used Forbidden Spinjitzu to defeat her, Aspheera was imprisoned in the Ancient Pyramid for a millennium, after which she was accidentally freed by the Ninja. She promptly stole Kai's element, allowing her to reignite her forces.  Immediately, Aspheera swore revenge on Wu and sieged Ninjago City with a legion of Pyro Vipers and Elemental Cobras. Eventually, her rampage reached the Samurai X Cave, where she attacked Wu and the Ninja. Using the second Scroll of Forbidden Spinjitzu, the Ninja were able to incapacitate Aspheera - but not before she banished Zane to the Never-Realm. Aspheera is currently incarcerated in Kryptarium Prison.",
#  'powers_text': 'To much to explain',
#  'intelligence_score': 95,
#  'strength_score': 30,
#  'speed_score': 90,
#  'durability_score': 80,
#  'power_score': 100,
#  'combat_score': 100,
#  'superpowers': "['Ability Shift', 'Absorption', 'Accelerated Healing', 'Adaptation', 'Agility', 'Animal Attributes', 'Animal Control', 'Animal Oriented Powers', 'Banish', 'Cold Resistance', 'Darkforce Manipulation', 'Dexterity', 'Dream Manipulation', 'Dream Manipulation', 'Durability', 'Element Control', 'Endurance', 'Energy Absorption', 'Enhanced Hearing', 'Enhanced Memory', 'Enhanced Senses', 'Enhanced Sight', 'Enhanced Smell', 'Existence Erasure', 'Fire Control', 'Fire Resistance', 'Flight', 'Force Fields', 'Heat Generation', 'Heat Resistance', 'Illusions', 'Immortality', 'Insanity', 'Intelligence', 'Invisibility', 'Invulnerability', 'Longevity', 'Magic', 'Magic Resistance', 'Marksmanship', 'Master Tactician', 'Matter Absorption', 'Melting', 'Memory Manipulation', 'Natural Armor', 'Natural Weapons', 'Peak Human Condition', 'Perfect Recollection', 'Photographic Reflexes', 'Power Absorption', 'Power Augmentation', 'Power Nullifier', 'Reflexes', 'Self-Sustenance', 'Smoke Manipulation', 'Spinjitzu', 'Stamina', 'Stealth', 'Summoning', 'Super Speed', 'Super Strength', 'Teleportation', 'Weapon-based Powers', 'Weapons Master']",
#  'alter_egos': '[]',
#  'aliases': "['Queen Aspheera']",
#  'place_of_birth': 'Ninjago',
#  'first_appearance': 'Wasted True Potential (Dream) /70674 Fire Fang',
#  'creator': nan,
#  'alignment': 'Bad',
#  'occupation': 'Leader of the pyro vipers',
#  'base': 'Mobile (fire fang)',
#  'teams': '[]',
#  'relatives': 'none',
#  'gender': 'Female',
#  'type_race': 'Animal',
#  'height': "5'10 • 178 cm",
#  'weight': '198 lb • 89 kg',
#  'eye_color': 'Red',
#  'hair_color': 'No Hair',
#  'skin_color': 'Gold',
#  'img': '/pictures2/portraits/10/050/16951.jpg?v=1578842389',
#  'has_electrokinesis': 0.0,
#  'has_energy_constructs': 0.0,
#  'has_mind_control_resistance': 0.0,
#  'has_matter_manipulation': 0.0,
#  'has_telepathy_resistance': 0.0,
#  'has_mind_control': 0.0,
#  'has_enhanced_hearing': 1.0,
#  'has_dimensional_travel': 0.0,
#  'has_element_control': 1.0,
#  'has_size_changing': 0.0,
#  'has_fire_resistance': 1.0,
#  'has_fire_control': 1.0,
#  'has_dexterity': 1.0,
#  'has_reality_warping': 0.0,
#  'has_illusions': 1.0,
#  'has_energy_beams': 0.0,
#  'has_peak_human_condition': 1.0,
#  'has_shapeshifting': 0.0,
#  'has_heat_resistance': 1.0,
#  'has_jump': 0.0,
#  'has_self-sustenance': 1.0,
#  'has_energy_absorption': 1.0,
#  'has_cold_resistance': 1.0,
#  'has_magic': 1.0,
#  'has_telekinesis': 0.0,
#  'has_toxin_and_disease_resistance': 0.0,
#  'has_telepathy': 0.0,
#  'has_regeneration': 0.0,
#  'has_immortality': 1.0,
#  'has_teleportation': 1.0,
#  'has_force_fields': 1.0,
#  'has_energy_manipulation': 0.0,
#  'has_endurance': 1.0,
#  'has_longevity': 1.0,
#  'has_weapon-based_powers': 1.0,
#  'has_energy_blasts': 0.0,
#  'has_enhanced_senses': 1.0,
#  'has_invulnerability': 1.0,
#  'has_stealth': 1.0,
#  'has_marksmanship': 1.0,
#  'has_flight': 1.0,
#  'has_accelerated_healing': 1.0,
#  'has_weapons_master': 1.0,
#  'has_intelligence': 1.0,
#  'has_reflexes': 1.0,
#  'has_super_speed': 1.0,
#  'has_durability': 1.0,
#  'has_stamina': 1.0,
#  'has_agility': 1.0,
#  'has_super_strength': 1.0}

# %% [markdown]
# # Data Transformation

# %%
# Separate Numerical Data and Categorical Data for transformation

numeric_cols = ['overall_score', 'intelligence_score', 'strength_score', 
               'speed_score', 'durability_score', 'power_score', 'combat_score']
numeric_data = df[numeric_cols]

categorical_data = df.drop(numeric_cols + ['height', 'weight', 'img'], axis=1)

# %% [markdown]
# ### Categorical Data

# %%
# convert list columns to text

categorical_data['superpowers'] = categorical_data['superpowers'].apply(lambda x: ",".join(ast.literal_eval(x)))
categorical_data['alter_egos'] = categorical_data['alter_egos'].apply(lambda x: ",".join(ast.literal_eval(x)))
categorical_data['aliases'] = categorical_data['aliases'].apply(lambda x: ",".join(ast.literal_eval(x)))
categorical_data['teams'] = categorical_data['teams'].apply(lambda x: ",".join(ast.literal_eval(x)))

# %%
# Replace NaN records with Empty Strings in history_text column
categorical_data['history_text'] = categorical_data['history_text'].apply(lambda x: "" if isinstance(x, float) else x)

# %% [markdown]
# We have `History` & `Power Text` about every superhero in the given dataset. Although this is rich description about each superhero, it still contains noise. We need to extract the key-information (keywords) from these two columns and remove the remaining text. <br>
# For this we will be using two packages - KeyBERT and TextRank

# %% [markdown]
# #### KeyBERT

# %%
# Extract Keywords and noun chucks from `history text` using KeyBERT Package

kw_model = KeyBERT(model='all-mpnet-base-v2')
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
# Example output from KeyBERT
[key for (key, score) in kw_model.extract_keywords(categorical_data['history_text'].iloc[560], vectorizer=KeyphraseTfidfVectorizer(), use_mmr=True,)]
# Out:
# ['sardonic superhero',
#  'hancock',
#  'pr executive ray embrey',
#  'good citizens',
#  'countless lives']

# %%
# Compute Keywords using KeyBERT and store them

keywords = []
for index, text in enumerate(categorical_data['history_text']):
  if len(text.split(' ')) <=1 :
    keywords.append("")
    continue
  keywords.append(",".join([key for (key, score) in kw_model.extract_keywords(text, vectorizer=KeyphraseTfidfVectorizer(), use_mmr=True)]))

# %%
categorical_data['history_keywords'] = keywords

# %%
# Drop History Text Column
categorical_data.drop('history_text', axis=1, inplace=True)

# %%
# Drop the One-Hot Encoded Columns because we have `superpowers` column 
# which describes all the super-powers

cols = [col_name for col_name in categorical_data.columns if col_name.startswith('has_')]
categorical_data.drop(cols, axis=1, inplace=True)

# %%
# Extract Keywords and noun chucks from `powers_text` using KeyBERT Package

categorical_data['powers_text'] = categorical_data['powers_text'].apply(lambda x: "" if isinstance(x, float) else x)

# %%
keywords = []
for index, text in enumerate(categorical_data['powers_text']):
  if len(text.split(' ')) <=1 :
    keywords.append("")
    continue
  keywords.append(",".join([key for (key, score) in kw_model.extract_keywords(text, use_mmr=True)]))

# %%
categorical_data['power_keywords'] = keywords

# %%
# Drop Powers Text Column
categorical_data.drop('powers_text', axis=1, inplace=True)

# %%
# Replace Missing NaN values with Empty String

categorical_data = categorical_data.replace(np.nan, '', regex=True)

# %%
categorical_data
# Out:
#                name               real_name               full_name  \
# 0           3-D Man     Delroy Garrett, Jr.     Delroy Garrett, Jr.
# 1     514A (Gotham)             Bruce Wayne
# 2            A-Bomb  Richard Milhouse Jones  Richard Milhouse Jones
# 3                Aa                      Aa
# 4        Aaron Cash              Aaron Cash              Aaron Cash
# ...             ...                     ...                     ...
# 1445        Zatanna          Zatanna Zatara          Zatanna Zatara
# 1446           Zero             DWN-∞: Zero             DWN-∞: Zero
# 1447  Zoom (New 52)          Hunter Zolomon
# 1448           Zoom          Hunter Zolomon          Hunter Zolomon
# 1449          Zzzax
#
#                                             superpowers  \
# 0                            Super Speed,Super Strength
# 1                    Durability,Reflexes,Super Strength
# 2     Accelerated Healing,Agility,Berserk Mode,Blood...
# 3     Energy Absorption,Energy Armor,Energy Beams,En...
# 4                    Weapon-based Powers,Weapons Master
# ...                                                 ...
# 1445  Cryokinesis,Fire Control,Magic,Probability Man...
# 1446  Accelerated Healing,Acrobatics,Agility,Cold Re...
# 1447  Accelerated Healing,Agility,Durability,Electro...
# 1448  Intangibility,Super Speed,Time Manipulation,Ti...
# 1449  Absorption,Agility,Electrokinesis,Element Cont...
#
#                                              alter_egos  \
# 0
# 1     Batgod,Batman,Batman (1966),Batman (Arkham),Ba...
# 2
# 3
# 4
# ...                                                 ...
# 1445  Chaos Zatanna,Doctor Fate,Zatanna (Full Potent...
# 1446
# 1447                    Black Flash (CW),Zoom,Zoom (CW)
# 1448           Black Flash (CW),Zoom (CW),Zoom (New 52)
# 1449
#
#                                 aliases  \
# 0
# 1      Subject 514A,Bruce Wayne,Bruce 2
# 2                            Rick Jones
# 3
# 4
# ...                                 ...
# 1445
# 1446
# 1447  Judge · Reverse-Flash · The Flash
# 1448
# 1449           The Living Dynamo, Rozzz
#
#                                  place_of_birth  \
# 0
# 1
# 2                            Scarsdale, Arizona
# 3                                    Stoneworld
# 4                                   Gotham City
# ...                                         ...
# 1445
# 1446
# 1447
# 1448
# 1449  Consolidated Edison Power Plant, New York
#
#                              first_appearance        creator alignment  \
# 0                                              Marvel Comics      Good
# 1                                                  DC Comics
# 2     Hulk Vol 2 #2 (April, 2008) (as A-Bomb)  Marvel Comics      Good
# 3                     Green Lantern Vol 3 #21      DC Comics      Good
# 4                                                  DC Comics      Good
# ...                                       ...            ...       ...
# 1445                               Hawkman #4      DC Comics      Good
# 1446                        Mega Man X (1993)         Capcom      Good
# 1447        Flash Secret Files and Origins #3      DC Comics       Bad
# 1448                   Flash Secret Files #3       DC Comics       Bad
# 1449                     Incredible Hulk #166  Marvel Comics       Bad
#
#                                              occupation  \
# 0
# 1
# 2     Musician, adventurer, author; formerly talk sh...
# 3
# 4
# ...                                                 ...
# 1445
# 1446
# 1447      Criminal · former F.B.I. Profiler, Politician
# 1448
# 1449                            Purveyor of destruction
#
#                        base  \
# 0
# 1
# 2
# 3
# 4
# ...                     ...
# 1445
# 1446
# 1447  Keystone City, Kansas
# 1448  Keystone City, Kansas
# 1449
#
#                                                   teams  \
# 0         Annihilators,Asgardians,Avengers,New Avengers
# 1
# 2     Teen Brigade,Ultimate Fantastic Four,U-Men,God...
# 3     Blue Lantern Corps,Green Lantern Corps,Justice...
# 4
# ...                                                 ...
# 1445  Seven Soldiers of Victory,Sentinels of Magic,Y...
# 1446
# 1447                                       Flash Family
# 1448  Rogues,The Society,Flash Family,Justice League...
# 1449                                West Coast Avengers
#
#                                               relatives  gender type_race  \
# 0                                                          Male     Human
# 1                        Bruce Wayne (genetic template)
# 2     Marlo Chandler-Jones (wife); Polly (aunt); Mrs...    Male     Human
# 3                                                          Male     Human
# 4                                                          Male     Human
# ...                                                 ...     ...       ...
# 1445  Giovanni "John" Zatara (father, deceased), Sin...  Female     Human
# 1446                                                       Male     Robot
# 1447                           Ashley Zolomon (ex-wife)    Male
# 1448                           Ashley Zolomon (ex-wife)    Male
# 1449
#
#      eye_color hair_color skin_color  \
# 0
# 1
# 2       Yellow    No Hair
# 3
# 4
# ...        ...        ...        ...
# 1445      Blue      Black
# 1446      Blue      Blond        Red
# 1447       Red      Brown
# 1448       Red      Brown
# 1449   No eyes    No Hair
#
#                                        history_keywords  \
# 0     delroy garrett,triune understanding,steroids,n...
# 1     bruce wayne look,alfred catch,selina kyle,subj...
# 2     hulk,rick radiation poisoning,jones,gamma bomb...
# 3     green lantern corps,comatose star sapphire,hal...
# 4        aaron cash,hook,killer croc,arkham asylum,hand
# ...                                                 ...
# 1445  zatanna,evil witch allura,john constantine,mag...
# 1446  mega man zero concept,unconscious zero,maveric...
# 1447  hunter zolomon,flash,zoom,former friend wally ...
# 1448  hunter zolomon,barry,current flash,car acciden...
# 1449  zzzax,atomic reactor,own consciousness,collect...
#
#                                   power_keywords
# 0
# 1
# 2     jones,superhuman,force,radiation,transform
# 3
# 4
# ...                                          ...
# 1445   zatanna,spellcasting,telepathic,able,does
# 1446
# 1447             zoom,speed,force,hunter,conduit
# 1448          speeds,zoom,superman,flashes,force
# 1449
#
# [1450 rows x 21 columns]

# %%
categorical_data = pd.read_parquet('/content/superhero_nlp_categorical_data.gzip')

# %%
# The Alignment Column has text like "Good" & "Bad". Lets add more terms 
# to provide verbose description

def alignment_aug(text:str) -> str:

  if text == "":
    return ""

  if text == 'Good':
    return f'{text}, Hero, Saviour, Protector of Justice'
  else:
    return f'{text}, Villan, Enemy, Destroyer, Mischief, Evil'

categorical_data['alignment'] = categorical_data['alignment'].apply(lambda x: alignment_aug(x))

# %% [markdown]
# #### Text Rank

# %%
# Spacy Transformer Model
nlp = spacy.load("en_core_web_trf")
# add PyTextRank to the spaCy pipeline
nlp.add_pipe("textrank")

# %%
def get_textkank_keywords(text: str, spacy_model: spacy.lang.en.English = nlp) -> list:
  # get keywords and then clean stopwords
  my_doc = nlp(text)

  # Create list of word tokens
  token_list = []
  for token in my_doc:
      token_list.append(token.text)

  filtered_sentence =[] 

  for word in token_list:
    lexeme = nlp.vocab[word]
    if lexeme.is_stop == False:
        filtered_sentence.append(word) 
  
  text = " ".join(filtered_sentence)

  keywords = []
  doc = nlp(text.lower())
  for phrase in doc._.phrases:
    keywords.append(phrase.text)
  return list(set(keywords))

# %%
df['history_text'] = df['history_text'].apply(lambda x: "" if isinstance(x, float) else x)

# %%
keywords = []
for index, text in enumerate(df['history_text']):
  print(f'index: {index}')
  if len(text.split(' ')) <=1 :
    keywords.append("")
    continue
  keywords.append(get_textkank_keywords(text))
# Out:
# index: 0
# index: 1
# index: 2
# index: 3
# index: 4
# index: 5
# index: 6
# index: 7
# index: 8
# index: 9
# index: 10
# index: 11
# index: 12
# index: 13
# index: 14
# index: 15
# index: 16
# index: 17
# index: 18
# index: 19
# index: 20
# index: 21
# index: 22
# index: 23
# index: 24
# index: 25
# index: 26
# index: 27
# index: 28
# index: 29
# index: 30
# index: 31
# index: 32
# index: 33
# index: 34
# index: 35
# index: 36
# index: 37
# index: 38
# index: 39
# index: 40
# index: 41
# index: 42
# index: 43
# index: 44
# index: 45
# index: 46
# index: 47
# index: 48
# index: 49
# index: 50
# index: 51
# index: 52
# index: 53
# index: 54
# index: 55
# index: 56
# index: 57
# index: 58
# index: 59
# index: 60
# index: 61
# index: 62
# index: 63
# index: 64
# index: 65
# index: 66
# index: 67
# index: 68
# index: 69
# index: 70
# index: 71
# index: 72
# index: 73
# index: 74
# index: 75
# index: 76
# index: 77
# index: 78
# index: 79
# index: 80
# index: 81
# index: 82
# index: 83
# index: 84
# index: 85
# index: 86
# index: 87
# index: 88
# index: 89
# index: 90
# index: 91
# index: 92
# index: 93
# index: 94
# index: 95
# index: 96
# index: 97
# index: 98
# index: 99
# index: 100
# index: 101
# index: 102
# index: 103
# index: 104
# index: 105
# index: 106
# index: 107
# index: 108
# index: 109
# index: 110
# index: 111
# index: 112
# index: 113
# index: 114
# index: 115
# index: 116
# index: 117
# index: 118
# index: 119
# index: 120
# index: 121
# index: 122
# index: 123
# index: 124
# index: 125
# index: 126
# index: 127
# index: 128
# index: 129
# index: 130
# index: 131
# index: 132
# index: 133
# index: 134
# index: 135
# index: 136
# index: 137
# index: 138
# index: 139
# index: 140
# index: 141
# index: 142
# index: 143
# index: 144
# index: 145
# index: 146
# index: 147
# index: 148
# index: 149
# index: 150
# index: 151
# index: 152
# index: 153
# index: 154
# index: 155
# index: 156
# index: 157
# index: 158
# index: 159
# index: 160
# index: 161
# index: 162
# index: 163
# index: 164
# index: 165
# index: 166
# index: 1403
# index: 1404
# index: 1405
# index: 1406
# index: 1407
# index: 1408
# index: 1409
# index: 1410
# index: 1411
# index: 1412
# index: 1413
# index: 1414
# index: 1415
# index: 1416
# index: 1417
# index: 1418
# index: 1419
# index: 1420
# index: 1421
# index: 1422
# index: 1423
# index: 1424
# index: 1425
# index: 1426
# index: 1427
# index: 1428
# index: 1429
# index: 1430
# index: 1431
# index: 1432
# index: 1433
# index: 1434
# index: 1435
# index: 1436
# index: 1437
# index: 1438
# index: 1439
# index: 1440
# index: 1441
# index: 1442
# index: 1443
# index: 1444
# index: 1445
# index: 1446
# index: 1447
# index: 1448
# index: 1449

# %%
categorical_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7c4a16eb81d4> in <module>
# ----> 1 categorical_data
#
# NameError: name 'categorical_data' is not defined

# %%
categorical_data['history_textrank_keywords'] = keywords

# %%
categorical_data[''] = categorical_data[''] + categorical_data['history_textrank_keywords']

# %% [markdown]
# ### Numeric Data

# %%
# map all ∞ values to 10,000, - to 0 and convert column type to int

numeric_data['overall_score'] = numeric_data['overall_score'].str.replace('∞','10000')
numeric_data['overall_score'] = numeric_data['overall_score'].str.replace('-','0')
numeric_data['overall_score'] = pd.to_numeric(numeric_data['overall_score'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
# This isn't providing much information. So removing it

numeric_data.drop('combat_score', axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
def generate_settings(dataset: pd.DataFrame, numeric_labels: dict):
  # Generating required setting for converting numbers to categorical classes
  settings = {}
  for col in dataset:
    
    if col == 'overall_score':
      score_bucket = [0,50,100,10_000]
    else:
      score_bucket = [0,50,100]

    x = {
        "labels": numeric_labels.get(col),
        "bucket": score_bucket
    }
    settings[col] = x
  return settings

# %%
numeric_labels = {
    "overall_score": ["feeble, powerless, frail, puny, delicate, faint", 
                      "moderate, capable, average, middle, decent, adequate", 
                      "most powerfull, invincible, god like, all mighty, supreme"],
    "intelligence_score": ["dumb, dim witted, stupid, unintelligent, brainless, foolish",
                           "smart, clever, bright, intelligent, acute, shrewd, sharpe witted, educated"],
    "strength_score": ["weak, fragile, weakly, infirm, sick, sickly, shaky, debilitated, ailing,, decrepit, enervated", 
                       "super strong, beast, powerful, muscular, brawny, well built, sturdy, hefty,, fit, athletic, vigorous"],
    "speed_score": ["slow, unhurried, slow-moving, slow-going, relaxed, laggard, dawdler, slowpoke, plodding, inert", 
                    "fast, speedy, quick, swift, rapid, brisk, nimble, sprightly, high-speed, turbo, sporty, accelerated, express, supersonic"],
    "durability_score": ["weak, breakable, easily broken, brittle, frangible, smashable, splintery, flimsy, delicate, fracturable", 
                         "long-lasting, hard-wearing, heavy-duty, tough, resistant, strong, sturdy, stout, sound, substantial, imperishable, indestructible"],
    "power_score": ["weak, helpless, useless, vulnerable, without power, powerless, ineffectual, inadequate, ineffective, defenseless, vulnerable, gutless, disenfranchised", 
                    "super strong, all-powerful, authoritative, capable, compelling, dominant, influential, mighty, persuasive, potent, strengthy sturdy"]
}

# %%
numeric_to_text = generate_settings(numeric_data, numeric_labels)

# %%
numeric_to_text
# Out:
# {'overall_score': {'labels': ['feeble, powerless, frail, puny, delicate, faint',
#    'moderate, capable, average, middle, decent, adequate',
#    'most powerfull, invincible, god like, all mighty, supreme'],
#   'bucket': [0, 25, 75, 10000]}}

# %%
# Map numerical ranges to classes
# Converting numerical data to categorical data

for col in numeric_to_text:
  numeric_data[col] = pd.cut(numeric_data[col], bins=numeric_to_text.get(col).get('bucket'), labels=numeric_to_text.get(col).get('labels'))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
superhero_description_df = pd.concat([categorical_data, numeric_data], axis=1)

# %% [markdown]
# ### Combined Data

# %%
superhero_description_df
# Out:
#                name               real_name               full_name  \
# 0           3-D Man     Delroy Garrett, Jr.     Delroy Garrett, Jr.
# 1     514A (Gotham)             Bruce Wayne
# 2            A-Bomb  Richard Milhouse Jones  Richard Milhouse Jones
# 3                Aa                      Aa
# 4        Aaron Cash              Aaron Cash              Aaron Cash
# ...             ...                     ...                     ...
# 1445        Zatanna          Zatanna Zatara          Zatanna Zatara
# 1446           Zero             DWN-∞: Zero             DWN-∞: Zero
# 1447  Zoom (New 52)          Hunter Zolomon
# 1448           Zoom          Hunter Zolomon          Hunter Zolomon
# 1449          Zzzax
#
#                                             superpowers  \
# 0                            Super Speed,Super Strength
# 1                    Durability,Reflexes,Super Strength
# 2     Accelerated Healing,Agility,Berserk Mode,Blood...
# 3     Energy Absorption,Energy Armor,Energy Beams,En...
# 4                    Weapon-based Powers,Weapons Master
# ...                                                 ...
# 1445  Cryokinesis,Fire Control,Magic,Probability Man...
# 1446  Accelerated Healing,Acrobatics,Agility,Cold Re...
# 1447  Accelerated Healing,Agility,Durability,Electro...
# 1448  Intangibility,Super Speed,Time Manipulation,Ti...
# 1449  Absorption,Agility,Electrokinesis,Element Cont...
#
#                                              alter_egos  \
# 0
# 1     Batgod,Batman,Batman (1966),Batman (Arkham),Ba...
# 2
# 3
# 4
# ...                                                 ...
# 1445  Chaos Zatanna,Doctor Fate,Zatanna (Full Potent...
# 1446
# 1447                    Black Flash (CW),Zoom,Zoom (CW)
# 1448           Black Flash (CW),Zoom (CW),Zoom (New 52)
# 1449
#
#                                 aliases  \
# 0
# 1      Subject 514A,Bruce Wayne,Bruce 2
# 2                            Rick Jones
# 3
# 4
# ...                                 ...
# 1445
# 1446
# 1447  Judge · Reverse-Flash · The Flash
# 1448
# 1449           The Living Dynamo, Rozzz
#
#                                  place_of_birth  \
# 0
# 1
# 2                            Scarsdale, Arizona
# 3                                    Stoneworld
# 4                                   Gotham City
# ...                                         ...
# 1445
# 1446
# 1447
# 1448
# 1449  Consolidated Edison Power Plant, New York
#
#                              first_appearance        creator  \
# 0                                              Marvel Comics
# 1                                                  DC Comics
# 2     Hulk Vol 2 #2 (April, 2008) (as A-Bomb)  Marvel Comics
# 3                     Green Lantern Vol 3 #21      DC Comics
# 4                                                  DC Comics
# ...                                       ...            ...
# 1445                               Hawkman #4      DC Comics
# 1446                        Mega Man X (1993)         Capcom
# 1447        Flash Secret Files and Origins #3      DC Comics
# 1448                   Flash Secret Files #3       DC Comics
# 1449                     Incredible Hulk #166  Marvel Comics
#
#                                           alignment  \
# 0         Good, Hero, Saviour, Protector of Justice
# 1
# 2         Good, Hero, Saviour, Protector of Justice
# 3         Good, Hero, Saviour, Protector of Justice
# 4         Good, Hero, Saviour, Protector of Justice
# ...                                             ...
# 1445      Good, Hero, Saviour, Protector of Justice
# 1446      Good, Hero, Saviour, Protector of Justice
# 1447  Bad, Villan, Enemy, Destroyer, Mischief, Evil
# 1448  Bad, Villan, Enemy, Destroyer, Mischief, Evil
# 1449  Bad, Villan, Enemy, Destroyer, Mischief, Evil
#
#                                              occupation  \
# 0
# 1
# 2     Musician, adventurer, author; formerly talk sh...
# 3
# 4
# ...                                                 ...
# 1445
# 1446
# 1447      Criminal · former F.B.I. Profiler, Politician
# 1448
# 1449                            Purveyor of destruction
#
#                        base  \
# 0
# 1
# 2
# 3
# 4
# ...                     ...
# 1445
# 1446
# 1447  Keystone City, Kansas
# 1448  Keystone City, Kansas
# 1449
#
#                                                   teams  \
# 0         Annihilators,Asgardians,Avengers,New Avengers
# 1
# 2     Teen Brigade,Ultimate Fantastic Four,U-Men,God...
# 3     Blue Lantern Corps,Green Lantern Corps,Justice...
# 4
# ...                                                 ...
# 1445  Seven Soldiers of Victory,Sentinels of Magic,Y...
# 1446
# 1447                                       Flash Family
# 1448  Rogues,The Society,Flash Family,Justice League...
# 1449                                West Coast Avengers
#
#                                               relatives  gender type_race  \
# 0                                                          Male     Human
# 1                        Bruce Wayne (genetic template)
# 2     Marlo Chandler-Jones (wife); Polly (aunt); Mrs...    Male     Human
# 3                                                          Male     Human
# 4                                                          Male     Human
# ...                                                 ...     ...       ...
# 1445  Giovanni "John" Zatara (father, deceased), Sin...  Female     Human
# 1446                                                       Male     Robot
# 1447                           Ashley Zolomon (ex-wife)    Male
# 1448                           Ashley Zolomon (ex-wife)    Male
# 1449
#
#      eye_color hair_color skin_color  \
# 0
# 1
# 2       Yellow    No Hair
# 3
# 4
# ...        ...        ...        ...
# 1445      Blue      Black
# 1446      Blue      Blond        Red
# 1447       Red      Brown
# 1448       Red      Brown
# 1449   No eyes    No Hair
#
#                                        history_keywords  \
# 0     delroy garrett,triune understanding,steroids,n...
# 1     bruce wayne look,alfred catch,selina kyle,subj...
# 2     hulk,rick radiation poisoning,jones,gamma bomb...
# 3     green lantern corps,comatose star sapphire,hal...
# 4        aaron cash,hook,killer croc,arkham asylum,hand
# ...                                                 ...
# 1445  zatanna,evil witch allura,john constantine,mag...
# 1446  mega man zero concept,unconscious zero,maveric...
# 1447  hunter zolomon,flash,zoom,former friend wally ...
# 1448  hunter zolomon,barry,current flash,car acciden...
# 1449  zzzax,atomic reactor,own consciousness,collect...
#
#                                   power_keywords  \
# 0
# 1
# 2     jones,superhuman,force,radiation,transform
# 3
# 4
# ...                                          ...
# 1445   zatanna,spellcasting,telepathic,able,does
# 1446
# 1447             zoom,speed,force,hunter,conduit
# 1448          speeds,zoom,superman,flashes,force
# 1449
#
#                                         overall_score
# 0     feeble, powerless, frail, puny, delicate, faint
# 1     feeble, powerless, frail, puny, delicate, faint
# 2     feeble, powerless, frail, puny, delicate, faint
# 3     feeble, powerless, frail, puny, delicate, faint
# 4     feeble, powerless, frail, puny, delicate, faint
# ...                                               ...
# 1445  feeble, powerless, frail, puny, delicate, faint
# 1446  feeble, powerless, frail, puny, delicate, faint
# 1447  feeble, powerless, frail, puny, delicate, faint
# 1448  feeble, powerless, frail, puny, delicate, faint
# 1449  feeble, powerless, frail, puny, delicate, faint
#
# [1450 rows x 22 columns]

# %%
def generate_description(data: pd.DataFrame) -> pd.DataFrame:

  def description_template(row: pd.Series) -> str:
    
    if row["gender"] == "Male":
      pro_noun_1 = "He"
      pro_noun_2 = "His"
    elif row["gender"] == "Female":
      pro_noun_1 = "She"
      pro_noun_2 = "Her"
    else:
      pro_noun_1 = "They"
      pro_noun_2 = "Their"

    # | {row["intelligence_score"]} | {row["strength_score"]} | {row["speed_score"]} | {row["durability_score"]} | {row["power_score"]}
    
    return f"""
    Full Name: {row["real_name"].lower()} | {row["full_name"]}.
    {pro_noun_2} super powers are {row["superpowers"]}. 
    Some of {pro_noun_2} alter egos are {row["alter_egos"]}.
    {pro_noun_1} also goes by {row["aliases"]}. 
    {pro_noun_2} place of birth is {row["place_of_birth"]}.
    {pro_noun_1} first appeared in {row["first_appearance"]}.
    This character was created by {row["creator"]}.
    {pro_noun_1} fights for {row["alignment"]}.
    {pro_noun_2} occupation is {row["occupation"]}.
    {pro_noun_1} is usually at {row["base"]}.
    This character is part of {row["teams"]}.
    {pro_noun_2} relatives are {row["relatives"]}.
    {pro_noun_1} belongs to {row["type_race"]}.
    Face Attributes are:  {row["eye_color"]}, {row["hair_color"]}, {row["skin_color"]}.
    History Keywords are {row["history_keywords"]}.
    Powers are {row["power_keywords"]}.
    Over all attributes are {row["overall_score"]}.
    """
  description_data = {
      "hero_name": [],
      "hero_description": []
  }


  for index, row in data.iterrows():
    description = description_template(row)
    description_data['hero_name'].append(row["name"])
    description_data['hero_description'].append(description.lower())
  
  df = pd.DataFrame(description_data)
  df['hero_description'] = df['hero_description'].apply(lambda x: re.sub("\n", "", x))
  df['hero_description'] = df['hero_description'].apply(lambda x: re.sub(r'\s+', " ", x))
  return df

# %%
superhero_description_text_df = generate_description(superhero_description_df)

# %%
superhero_description_text_df
# Out:
#           hero_name                                   hero_description
# 0           3-D Man   full name: delroy garrett, jr. | delroy garre...
# 1     514A (Gotham)   full name: bruce wayne | . their super powers...
# 2            A-Bomb   full name: richard milhouse jones | richard m...
# 3                Aa   full name: aa | . his super powers are energy...
# 4        Aaron Cash   full name: aaron cash | aaron cash. his super...
# ...             ...                                                ...
# 1445        Zatanna   full name: zatanna zatara | zatanna zatara. h...
# 1446           Zero   full name: dwn-∞: zero | dwn-∞: zero. his sup...
# 1447  Zoom (New 52)   full name: hunter zolomon | . his super power...
# 1448           Zoom   full name: hunter zolomon | hunter zolomon. h...
# 1449          Zzzax   full name: | . their super powers are absorpt...
#
# [1450 rows x 2 columns]

# %%
# superhero_description_text_df.to_parquet('superhero_desc.gzip', compression='gzip')

# %% [markdown]
# # Semantic Search

# %%
superhero_description_text_df = pd.read_parquet('/content/superhero_desc.gzip')

# %%
superhero_description_text_df
# Out:
#           hero_name                                   hero_description
# 0           3-D Man   full name: delroy garrett, jr. | delroy garre...
# 1     514A (Gotham)   full name: bruce wayne | . their super powers...
# 2            A-Bomb   full name: richard milhouse jones | richard m...
# 3                Aa   full name: aa | . his super powers are energy...
# 4        Aaron Cash   full name: aaron cash | aaron cash. his super...
# ...             ...                                                ...
# 1445        Zatanna   full name: zatanna zatara | zatanna zatara. h...
# 1446           Zero   full name: dwn-∞: zero | dwn-∞: zero. his sup...
# 1447  Zoom (New 52)   full name: hunter zolomon | . his super power...
# 1448           Zoom   full name: hunter zolomon | hunter zolomon. h...
# 1449          Zzzax   full name: | . their super powers are absorpt...
#
# [1450 rows x 2 columns]

# %%
embedding_model = SentenceTransformer('all-mpnet-base-v2')
embedding_size = 768    #Size of embeddings
top_k_hits = 3         #Output k hits
embedding_cache_path = f'superhero-embeddings-{embedding_size}-size.pkl'
# Out:
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
#Check if embedding cache path exists
if not os.path.exists(embedding_cache_path):

  # Embedding Cache is Not Present. Build Embeddings from Scratch
    print("Encoding the entire corpus as Embedding Cache is not present.\nThis might take a while")
    corpus_embeddings = embedding_model.encode(list(superhero_description_text_df['hero_description']),
                                               show_progress_bar=True, convert_to_numpy=True)

    print("Store file on disc")
    with open(embedding_cache_path, "wb") as fOut:
        pickle.dump({'hero_name': list(superhero_description_text_df['hero_name']),
                     'hero_description': list(superhero_description_text_df['hero_description']),
                     'hero_description_embeddings': corpus_embeddings}, fOut)
else:
    print("Load pre-computed embeddings from disc")
    with open(embedding_cache_path, "rb") as fIn:
        cache_data = pickle.load(fIn)
        hero_name = cache_data['hero_name']
        hero_description = cache_data['hero_description']
        hero_description_embeddings = cache_data['hero_description_embeddings']
# Out:
# Encoding the entire corpus as Embedding Cache is not present.
# This might take a while
# Batches:   0%|          | 0/46 [00:00<?, ?it/s]
# Store file on disc

# %%
index_path = "./hnswlib.index"
index = hnswlib.Index(space = 'cosine', dim = embedding_size)

# %%
if os.path.exists(index_path):
    print("Loading index...")
    index.load_index(index_path)
else:
    ### Create the HNSWLIB index
    print("Start creating HNSWLIB index")
    index.init_index(max_elements = len(corpus_embeddings), ef_construction = 400, M = 64)

    # Then we train the index to find a suitable clustering
    index.add_items(corpus_embeddings, list(range(len(corpus_embeddings))))

    print("Saving index to:", index_path)
    index.save_index(index_path)

# Controlling the recall by setting ef:
index.set_ef(50)  # ef should always be > top_k_hits
# Out:
# Start creating HNSWLIB index
# Saving index to: ./hnswlib.index

# %%
print("Corpus loaded with {} sentences / embeddings".format(len(list(superhero_description_text_df['hero_description']))))
# Out:
# Corpus loaded with 1450 sentences / embeddings

# %%
def guess_the_hero(description: str, top_k_hits:int=10) -> str:
  inp_hero_des_embedding = embedding_model.encode(description.lower())
  corpus_ids, distances = index.knn_query(inp_hero_des_embedding, k=top_k_hits)
  # We extract corpus ids and scores for the first query
  hits = [{'corpus_id': id, 'score': 1-score} for id, score in zip(corpus_ids[0], distances[0])]
  hits = sorted(hits, key=lambda x: x['score'], reverse=True)

  print("Input Hero Description:", description)
  for hit in hits[0:top_k_hits]:
    print("{:.3f}\t{}".format(hit['score'], superhero_description_text_df['hero_name'].iloc[hit['corpus_id']]))

# %%
# inp_hero_des = "Knight of Dark, Gotham protector, Smart, Intelligent, martial artist, master of dark, educated"

# %%
desc = "Smart, Intelligent, martial artist, master of darkness, educated, intelligent"
guess_the_hero(desc)
# Out:
# Input Hero Description: Smart, Intelligent, martial artist, master of darkness, educated, intelligent
# 0.495	Dark Kahn
# 0.485	Khanjikhan
# 0.483	Preeminent
# 0.482	Chosen Undead
# 0.480	A.M.A.Z.O. (CW)
# 0.474	Bryan Mills
# 0.472	Ancient One (MCU)
# 0.471	Wu
# 0.470	Deacons Of The Deep
# 0.468	Ultron (Final Form)

# %%
desc = "Gotham protector, Smart, Intelligent, martial artist, master of dark, educated"
guess_the_hero(desc)
# Out:
# Input Hero Description: Gotham protector, Smart, Intelligent, martial artist, master of dark, educated
# 0.706	Batman (DC One Million)
# 0.685	Harvey Bullock
# 0.660	Sea King
# 0.657	Batman (Injustice)
# 0.656	Batman (The Brave And The Bold)
# 0.654	Devastator
# 0.652	Alfred (DCEU)
# 0.652	Bane (Dark Knight)
# 0.645	Batman (DCAU)
# 0.641	Copperhead

# %%
superhero_description_text_df[superhero_description_text_df['hero_name'].str.contains(r'(^Superman.*)')==1]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
#                    hero_name  \
# 1253         Superman (2006)
# 1254  Superman (Post-Crisis)
# 1255   Superman (Smallville)
#
#                                        hero_description
# 1253   full name: kal-el | kal-el. his super powers ...
# 1254   full name: kal-el | clark joseph kent (kal-el...
# 1255   full name: kal-el | . his super powers are ab...

# %%
superhero_description_text_df.iloc[1253].values
# Out:
# array(['Superman (2006)',
#        ' full name: kal-el | kal-el. his super powers are absorption,cryokinesis,durability,element control,energy absorption,enhanced hearing,enhanced sight,flight,invulnerability,longevity,reflexes,regeneration,stamina,super breath,super speed,super strength,vision - heat,vision - telescopic. some of his alter egos are parallax,strange visitor superman,superboy-prime,superman (cw),superman (dceu),superman (donner),superman (earth one),superman (god of strength),superman (injustice),superman (kingdom come),superman (new 52),superman (post-crisis),superman (pre-crisis),superman (rebirth),superman (red lantern),superman (red son),superman (smallville),superman (strange visitor),superman (white lantern),superman (worthy),superman doomed,superman doomed (brainiac),superman prime one-million,superman red. he also goes by clark kent. his place of birth is krypton. he first appeared in superman returns. this character was created by dc comics. he fights for good, hero. his occupation is reporter. he is usually at metropolis. this character is part of . his relatives are jor-el (biological father), lara (biological mother, ), jonathan kent (adoptive father, ), martha kent (adoptive mother), jason white (son). he belongs to kryptonian. face attributes are: blue, black, . history keywords are fellow reporter lois lane,kryptonian,kal,richard donner universe,last son. powers are superman,kryptonians,sun,yellow,develops. over all attributes are feeble, powerless, frail, puny, delicate, faint | smart, clever, bright, intelligent, acute, shrewd, sharpe witted, educated | super strong, beast, powerful, muscular, brawny, well built, sturdy, hefty,, fit, athletic, vigorous | fast, speedy, quick, swift, rapid, brisk, nimble, sprightly, high-speed, turbo, sporty, accelerated, express, supersonic | long-lasting, hard-wearing, heavy-duty, tough, resistant, strong, sturdy, stout, sound, substantial, imperishable, indestructible | super strong, all-powerful, authoritative, capable, compelling, dominant, influential, mighty, persuasive, potent, strengthy sturdy. '],
#       dtype=object)
